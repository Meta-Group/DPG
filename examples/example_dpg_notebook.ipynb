# %% [markdown]
# # 🌳 Decision Predicate Graph (DPG)
# This notebook shows a minimal working example of using DPG on a classification dataset.

# %%
# %pip install git+https://github.com/Meta-Group/DPG.git
# Out:
# Collecting git+https://github.com/Meta-Group/DPG.git
#   Cloning https://github.com/Meta-Group/DPG.git to /tmp/pip-req-build-8cng9mbc
#   Running command git clone --filter=blob:none --quiet https://github.com/Meta-Group/DPG.git /tmp/pip-req-build-8cng9mbc
#   Resolved https://github.com/Meta-Group/DPG.git to commit a906954df2e4361f48bd10ceec3c49dec1a44b81
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: six==1.16.0 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from dpg==0.1.0) (1.16.0)
# Requirement already satisfied: pyparsing==3.1.2 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from dpg==0.1.0) (3.1.2)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.2 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from dpg==0.1.0) (6.0.2)
# Requirement already satisfied: networkx==3.3 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from dpg==0.1.0) (3.3)
# Requirement already satisfied: scipy>=1.14.0 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from dpg==0.1.0) (1.14.0)
# Requirement already satisfied: numpy>=2.0.0 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from dpg==0.1.0) (2.0.0)
# Requirement already satisfied: scikit-learn==1.5.1 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from dpg==0.1.0) (1.5.1)
# Requirement already satisfied: ipykernel<7.0.0,>=6.25.2 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from dpg==0.1.0) (6.31.0)
# Requirement already satisfied: packaging==24.1 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from dpg==0.1.0) (24.1)
# Requirement already satisfied: kiwisolver==1.4.5 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from dpg==0.1.0) (1.4.5)
# Requirement already satisfied: cycler==0.12.1 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from dpg==0.1.0) (0.12.1)
# Requirement already satisfied: seaborn<0.13.0,>=0.12.2 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from dpg==0.1.0) (0.12.2)
# Requirement already satisfied: fonttools==4.53.1 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from dpg==0.1.0) (4.53.1)
# Requirement already satisfied: tqdm==4.67.1 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from dpg==0.1.0) (4.67.1)
# Requirement already satisfied: pytz==2024.1 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from dpg==0.1.0) (2024.1)
# Requirement already satisfied: pandas==2.2.2 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from dpg==0.1.0) (2.2.2)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from dpg==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pillow==10.4.0 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from dpg==0.1.0) (10.4.0)
# Requirement already satisfied: matplotlib>=3.9.1 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from dpg==0.1.0) (3.9.1)
# Requirement already satisfied: contourpy==1.2.1 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from dpg==0.1.0) (1.2.1)
# Requirement already satisfied: threadpoolctl==3.5.0 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from dpg==0.1.0) (3.5.0)
# Requirement already satisfied: tzdata==2024.1 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from dpg==0.1.0) (2024.1)
# Requirement already satisfied: joblib==1.4.2 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from dpg==0.1.0) (1.4.2)
# Requirement already satisfied: graphviz==0.20.3 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from dpg==0.1.0) (0.20.3)
# Requirement already satisfied: pyzmq>=25 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from ipykernel<7.0.0,>=6.25.2->dpg==0.1.0) (27.1.0)
# Requirement already satisfied: debugpy>=1.6.5 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from ipykernel<7.0.0,>=6.25.2->dpg==0.1.0) (1.8.20)
# Requirement already satisfied: psutil>=5.7 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from ipykernel<7.0.0,>=6.25.2->dpg==0.1.0) (7.2.2)
# Requirement already satisfied: jupyter-client>=8.0.0 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from ipykernel<7.0.0,>=6.25.2->dpg==0.1.0) (8.8.0)
# Requirement already satisfied: traitlets>=5.4.0 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from ipykernel<7.0.0,>=6.25.2->dpg==0.1.0) (5.14.3)
# Requirement already satisfied: comm>=0.1.1 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from ipykernel<7.0.0,>=6.25.2->dpg==0.1.0) (0.2.3)
# Requirement already satisfied: nest-asyncio>=1.4 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from ipykernel<7.0.0,>=6.25.2->dpg==0.1.0) (1.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from ipykernel<7.0.0,>=6.25.2->dpg==0.1.0) (5.9.1)
# Requirement already satisfied: tornado>=6.2 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from ipykernel<7.0.0,>=6.25.2->dpg==0.1.0) (6.5.4)
# Requirement already satisfied: ipython>=7.23.1 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from ipykernel<7.0.0,>=6.25.2->dpg==0.1.0) (8.38.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from ipykernel<7.0.0,>=6.25.2->dpg==0.1.0) (0.2.1)
# Requirement already satisfied: exceptiongroup in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.25.2->dpg==0.1.0) (1.3.1)
# Requirement already satisfied: jedi>=0.16 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.25.2->dpg==0.1.0) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.25.2->dpg==0.1.0) (3.0.52)
# Requirement already satisfied: decorator in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.25.2->dpg==0.1.0) (5.2.1)
# Requirement already satisfied: pygments>=2.4.0 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.25.2->dpg==0.1.0) (2.19.2)
# Requirement already satisfied: typing_extensions>=4.6 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.25.2->dpg==0.1.0) (4.15.0)
# Requirement already satisfied: stack_data in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.25.2->dpg==0.1.0) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.25.2->dpg==0.1.0) (4.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel<7.0.0,>=6.25.2->dpg==0.1.0) (4.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel<7.0.0,>=6.25.2->dpg==0.1.0) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel<7.0.0,>=6.25.2->dpg==0.1.0) (0.7.0)
# Requirement already satisfied: wcwidth in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel<7.0.0,>=6.25.2->dpg==0.1.0) (0.5.3)
# Requirement already satisfied: pure-eval in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel<7.0.0,>=6.25.2->dpg==0.1.0) (0.2.3)
# Requirement already satisfied: asttokens>=2.1.0 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel<7.0.0,>=6.25.2->dpg==0.1.0) (3.0.1)
# Requirement already satisfied: executing>=1.2.0 in /home/barbon/Python/pipeline/DPG/.venv/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel<7.0.0,>=6.25.2->dpg==0.1.0) (2.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from dpg.core import DecisionPredicateGraph
from dpg.visualizer import plot_dpg

# %% [markdown]
# ## 📥 Load your dataset

# %%
# Assumes your dataset is in datasets/custom.csv
# Last column is the target
df = pd.read_csv("../datasets/custom.csv", index_col=0)
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %% [markdown]
# ## 🧠 Train a Random Forest

# %%
model = RandomForestClassifier(n_estimators=10, random_state=27)
model.fit(X, y)
# Out:
# RandomForestClassifier(n_estimators=10, random_state=27)

# %% [markdown]
# ## 📊 Generate and visualize DPG

# %%
feature_names = X.columns.tolist()
class_names = np.unique(y).astype(str).tolist()

dpg = DecisionPredicateGraph(
    model=model,
    feature_names=feature_names,
    target_names=class_names,
    decimal_threshold=2,
    n_jobs=1
)
dot = dpg.fit(X.values)
dpg_model, nodes_list = dpg.to_networkx(dot)

dpg_metrics = dpg.extract_graph_metrics(dpg_model, nodes_list)
df_nodes = dpg.extract_node_metrics(dpg_model, nodes_list)

plot_dpg("dpg_output.png", dot, df_nodes, dpg_metrics, save_dir="../datasets", communities=True, class_flag=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 feature_names = X.columns.tolist()
#       2 class_names = np.unique(y).astype(str).tolist()
# ----> 4 dpg = DecisionPredicateGraph(
#       5     model=model,
#       6     feature_names=feature_names,
#       7     target_names=class_names,
#       8     perc_var=0.01,
#       9     decimal_threshold=2,
#      10     n_jobs=1
#      11 )
#      12 dot = dpg.fit(X.values)
#      13 dpg_model, nodes_list = dpg.to_networkx(dot)
#
# TypeError: DecisionPredicateGraph.__init__() got an unexpected keyword argument 'perc_var'

# %% [markdown]
# ## Communities

# %%
import pandas as pd

rows = []
for group in dpg_metrics["Communities"]:
    class_name = [s for s in group if s.startswith("Class")][0]
    predicates = group - {class_name}
    for pred in predicates:
        rows.append({"Class": class_name, "Predicate": pred})

df = pd.DataFrame(rows)

# Group predicates by class
grouped_df = df.groupby("Class")["Predicate"].apply(lambda x: ", ".join(sorted(x))).reset_index()
grouped_df

# %% [markdown]
# ## Class Bounds

# %%
import pandas as pd

# Assuming dpg_metrics is already defined and contains "Class Bounds"
class_bounds = dpg_metrics.get("Class Bounds", {})

# Convert to DataFrame: one row per class with constraints joined
df_bounds = pd.DataFrame([
    {"Class": class_name, "Constraints": ", ".join(sorted(bounds))}
    for class_name, bounds in class_bounds.items()
])

# Optional: sort alphabetically by class name
df_bounds = df_bounds.sort_values("Class")
df_bounds

# %% [markdown]
# ## Predicates (nodes) explanation

# %%
import matplotlib.pyplot as plt

# Sort by Local Reaching Centrality
df_sorted = df_nodes.sort_values("Local reaching centrality", ascending=False).head(10)

# Plot
plt.figure(figsize=(10, 6))
plt.barh(df_sorted["Label"], df_sorted["Local reaching centrality"], color="skyblue")
plt.xlabel("Local Reaching Centrality")
plt.ylabel("Label")
plt.title("Ranking of Local Reaching Centrality (LRC)")
plt.gca().invert_yaxis()  # Highest at the top
plt.tight_layout()
plt.show()
